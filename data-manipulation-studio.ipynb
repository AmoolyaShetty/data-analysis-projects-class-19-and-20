# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np

df_baltimore = pd.read_csv(r"C:\Users\aigsh\Downloads\archive (14)\baltimore_9-24-2016_9-30-2017.csv")
df_boston = pd.read_csv(r"C:\Users\aigsh\Downloads\archive (14)\boston_9-24-2016_9-30-2017.csv")
df_new_york = pd.read_csv(r"C:\Users\aigsh\Downloads\archive (14)\new-york_9-24-2016_9-30-2017.csv")
df_philadelphia = pd.read_csv(r"C:\Users\aigsh\Downloads\archive (14)\philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
print('Baltimore')
for col in df_baltimore.columns:
    missing_values_percentage = np.mean(df_baltimore[col].isnull())
    print('{} - {}%'.format(col, round(missing_values_percentage*100)))
print('\n')

print('Boston')
for col in df_boston.columns:
    missing_values_percentage = np.mean(df_boston[col].isnull())
    print('{} - {}%'.format(col,round(missing_values_percentage*100)))
print('\n')

print('New_york')
for col in df_new_york.columns:
    missing_values_percentage = np.mean(df_new_york[col].isnull())
    print('{} -{}%'.format(col,round(missing_values_percentage*100)))
print('\n')

print('Philadelphia')
for col in df_philadelphia.columns:
    missing_values_percentage = np.mean(df_philadelphia[col].isnull())
    print('{} -{}%'.format(col,round(missing_values_percentage*100)))
print('\n')
# Out:
# Baltimore
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
#
#
# Boston
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
#
#
# New_york
# Commodity Name -0%
# City Name -0%
# Type -100%
# Package -0%
# Variety -0%
# Sub Variety -84%
# Grade -100%
# Date -0%
# Low Price -0%
# High Price -0%
# Mostly Low -0%
# Mostly High -0%
# Origin -0%
# Origin District -87%
# Item Size -7%
# Color -81%
# Environment -100%
# Unit of Sale -78%
# Quality -100%
# Condition -100%
# Appearance -100%
# Storage -100%
# Crop -100%
# Repack -0%
# Trans Mode -100%
#
#
# Philadelphia
# Commodity Name -0%
# City Name -0%
# Type -100%
# Package -0%
# Variety -0%
# Sub Variety -79%
# Grade -100%
# Date -0%
# Low Price -0%
# High Price -0%
# Mostly Low -0%
# Mostly High -0%
# Origin -0%
# Origin District -100%
# Item Size -21%
# Color -100%
# Environment -100%
# Unit of Sale -81%
# Quality -100%
# Condition -100%
# Appearance -100%
# Storage -100%
# Crop -100%
# Repack -0%
# Trans Mode -100%

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
combined_df_NE_region = pd.concat([df_baltimore, df_boston, df_new_york, df_philadelphia])
combined_df_NE_region
# Out:
#    Commodity Name     City Name  Type             Package      Variety  \
# 0        PUMPKINS     BALTIMORE   NaN        24 inch bins          NaN
# 1        PUMPKINS     BALTIMORE   NaN        24 inch bins          NaN
# 2        PUMPKINS     BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 3        PUMPKINS     BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# 4        PUMPKINS     BALTIMORE   NaN        24 inch bins  HOWDEN TYPE
# ..            ...           ...   ...                 ...          ...
# 52       PUMPKINS  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE
# 53       PUMPKINS  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE
# 54       PUMPKINS  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE
# 55       PUMPKINS  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE
# 56       PUMPKINS  PHILADELPHIA   NaN  1/2 bushel cartons    MINIATURE
#
#    Sub Variety  Grade        Date  Low Price  High Price  ...  Color  \
# 0          NaN    NaN  04/29/2017        270       280.0  ...    NaN
# 1          NaN    NaN  05/06/2017        270       280.0  ...    NaN
# 2          NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 3          NaN    NaN  09/24/2016        160       160.0  ...    NaN
# 4          NaN    NaN  11/05/2016         90       100.0  ...    NaN
# ..         ...    ...         ...        ...         ...  ...    ...
# 52   FLAT TYPE    NaN  11/05/2016         16        18.0  ...    NaN
# 53   FLAT TYPE    NaN  08/26/2017         18        20.0  ...    NaN
# 54   FLAT TYPE    NaN  09/16/2017         16        16.0  ...    NaN
# 55   FLAT TYPE    NaN  09/23/2017         15        16.0  ...    NaN
# 56   FLAT TYPE    NaN  09/30/2017         15        18.0  ...    NaN
#
#     Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0           NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1           NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2           NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3           NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4           NaN          NaN     NaN       NaN        NaN      NaN  NaN
# ..          ...          ...     ...       ...        ...      ...  ...
# 52          NaN   SHELLACKED     NaN       NaN        NaN      NaN  NaN
# 53          NaN   SHELLACKED     NaN       NaN        NaN      NaN  NaN
# 54          NaN   SHELLACKED     NaN       NaN        NaN      NaN  NaN
# 55          NaN   SHELLACKED     NaN       NaN        NaN      NaN  NaN
# 56          NaN   SHELLACKED     NaN       NaN        NaN      NaN  NaN
#
#     Repack  Trans Mode
# 0        E         NaN
# 1        E         NaN
# 2        N         NaN
# 3        N         NaN
# 4        N         NaN
# ..     ...         ...
# 52       N         NaN
# 53       N         NaN
# 54       N         NaN
# 55       N         NaN
# 56       N         NaN
#
# [674 rows x 25 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
Unit_sale_NE = combined_df_NE_region.groupby('Unit of Sale')
display(Unit_sale_NE['Low Price'].agg('mean'))
display(Unit_sale_NE['High Price'].agg('mean'))
# Out:
# Unit of Sale
# EACH           47.916667
# PER BIN       185.845070
# SHELLACKED     16.000000
# Name: Low Price, dtype: float64
# Unit of Sale
# EACH           59.166667
# PER BIN       206.619718
# SHELLACKED     17.545455
# Name: High Price, dtype: float64

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
Variety_NE = combined_df_NE_region.groupby(['Variety','City Name']).size().reset_index(name="Delivery Count")
delivery_NE = Variety_NE.groupby('Variety')['Delivery Count'].agg('mean')
delivery_NE
# Out:
# Variety
# BIG MACK TYPE               18.333333
# BLUE TYPE                    7.000000
# CINDERELLA                  19.500000
# FAIRYTALE                   18.500000
# HOWDEN TYPE                 56.000000
# HOWDEN WHITE TYPE            2.000000
# KNUCKLE HEAD                 3.000000
# MINIATURE                   24.250000
# MIXED HEIRLOOM VARIETIES     2.000000
# PIE TYPE                    49.500000
# Name: Delivery Count, dtype: float64

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
